# %%
from utils import AiDevsTask, OpenAIEmbedding
import json
import os
from langchain.schema import (
    SystemMessage,
    HumanMessage,
    AIMessage
)

# Usage example:
task_name = "embedding"
task = AiDevsTask()
task.get_token(task_name)
task_response = task.get_task_content()

task_msg = task_response['msg']
print("Task message: ", task_msg)

value = "Hawaiian pizza"

embedding = OpenAIEmbedding()
response = embedding.embed_query(value)
print("Response: ", response)

task.send_answer(response)
# Out:
# Token: 21ac15d8c765ae7a68214349fa2f39cb04389eaf
# Treść zadania:  {'code': 0, 'msg': 'send embedding of this sentence created via text-embedding-ada-002. Send me just array of params: Hawaiian pizza', 'hint1': 'this is required structure: [0.003750941, 0.0038711438, 0.0082909055, -0.008753223, -0.02073651, -0.018862579, -0.010596331, -0.022425512, ..., -0.026950065]', 'hint2': 'it must be a valid JSON array of numbers', 'hint3': 'just return as JSON array content of .data[0].embedding'}
# Task message:  send embedding of this sentence created via text-embedding-ada-002. Send me just array of params: Hawaiian pizza
# ...
