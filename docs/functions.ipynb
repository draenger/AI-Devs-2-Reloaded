# %%
from utils import AiDevsTask, OpenAIChat
import json
import os
from langchain.schema import (
    SystemMessage,
    HumanMessage,
    AIMessage
)

# Usage example:
task_name = "functions"
task = AiDevsTask()
task.get_token(task_name)
task_response = task.get_task_content()

task_msg = task_response['msg']
print("Task message: ", task_msg)

example= """{
   "name":"orderPizza",
   "description":"select pizza in pizzeria based on pizza name",
   "parameters":{
      "type":"object",
      "properties":{
         "name":{
            "type":"string",
            "description":"provide name of the pizza"
         }
      }
   }
}
"""

chatbot = OpenAIChat()
prompt = HumanMessage(content = f"""You need to return pure json schema for the given prompt: "{task_msg}". 
    ### Example  
    {example}
    ### Rules
    - The answer should be in JSON format
    - The answer should be a valid JSON schema
    - The answer should be well described, like it was shown in the example  
""")

results = chatbot.handle_query(prompt)
print(results)

serialized_results = json.loads(results)
task.send_answer(serialized_results)
# Out:
# Token: 9aee68cedb3862c533316ce8e664e1104d15af5f
# Treść zadania:  {'code': 0, 'msg': 'send me definition of function named addUser that require 3 params: name (string), surname (string) and year of birth in field named "year" (integer). Set type of function to "object"', 'hint1': "send this definition as correct JSON structure inside 'answer' field (as usual)"}
# Task message:  send me definition of function named addUser that require 3 params: name (string), surname (string) and year of birth in field named "year" (integer). Set type of function to "object"
# Prompt: You need to return pure json schema for the given prompt: "send me definition of function named addUser that require 3 params: name (string), surname (string) and year of birth in field named "year" (integer). Set type of function to "object"".
#     ### Example
#     {
#    "name":"orderPizza",
#    "description":"select pizza in pizzeria based on pizza name",
#    "parameters":{
#       "type":"object",
# ...
